# %% [markdown]
# # Web Scrapping

# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen
import logging

# %%
flipkart_url = "https://www.flipkart.com/search?q=" + "iphone14pro"

# %%
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=iphone14pro'

# %%
flipkart_url = "https://www.flipkart.com/search?q=" + "tv"

# %%
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=tv'

# %%
urlclient = urlopen(flipkart_url)

# %%
urlclient.read()
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.615ed9.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x5
# ...

# %%
flipkart_page = urlclient.read()

# %%
bs(flipkart_page, 'html.parser')

# %%
flipkart_html = bs(flipkart_page, 'html.parser')

# %%
"https://www.flipkart.com/" + "samsung-crystal-vision-4k-ismart-voice-assistant-108-cm-43-inch-ultra-hd-4k-led-smart-tizen-tv-2023-video-calling-iot-sensors-light-camera/p/itmc5650bbd93ddc?pid=TVSGRNGZGWNFGCZM&lid=LSTTVSGRNGZGWNFGCZMTFVV78&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&srno=s_1_1&otracker=search&fm=organic&iid=en_UU1-TE2dWEpsEQXf-6A-IrT3KcH4ZD1vLTL612CiibQhwimPsyavACUm4bwXBIxNjmKrlfjTMRIdEnrLu0TqWQ%3D%3D&ppt=None&ppn=None&ssid=olixsbs6yo0000001702564541241&qH=c9a1fdac6e082dd8"
# Out:
# 'https://www.flipkart.com/samsung-crystal-vision-4k-ismart-voice-assistant-108-cm-43-inch-ultra-hd-4k-led-smart-tizen-tv-2023-video-calling-iot-sensors-light-camera/p/itmc5650bbd93ddc?pid=TVSGRNGZGWNFGCZM&lid=LSTTVSGRNGZGWNFGCZMTFVV78&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&srno=s_1_1&otracker=search&fm=organic&iid=en_UU1-TE2dWEpsEQXf-6A-IrT3KcH4ZD1vLTL612CiibQhwimPsyavACUm4bwXBIxNjmKrlfjTMRIdEnrLu0TqWQ%3D%3D&ppt=None&ppn=None&ssid=olixsbs6yo0000001702564541241&qH=c9a1fdac6e082dd8'

# %%
boxes = flipkart_html.find_all("div", {"class":"_1AtVbE col-12-12"})

# %%
len(boxes)
# Out:
# 0

# %%
del boxes[0:3]

# %%
boxes[0].div.div.div
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 boxes[0].div.div.div
#
# IndexError: list index out of range

# %%
boxes[0].div.div.div.a
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 links[0].div.div.div.a
#
# IndexError: list index out of range

# %%
boxes[0].div.div.div.a['href']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 links[0].div.div.div.a['href']
#
# IndexError: list index out of range

# %%
"https://www.flipkart.com/" + boxes[0].div.div.div.a['href']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 "https://www.flipkart.com/" + links[0].div.div.div.a['href']
#
# IndexError: list index out of range

# %%
for i in boxes:
    print("https://www.flipkart.com" + i.div.div.div.a['href'])
    print('\n')

# %%
24:40
